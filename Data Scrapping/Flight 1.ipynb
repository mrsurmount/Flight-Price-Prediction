# %% [markdown]
# ### Importing the Required Libraries:-

# %%
import selenium
from selenium import webdriver
import time
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import NoSuchElementException

# %% [markdown]
# ### Opening the Driver:-

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %% [markdown]
# ### Giving the URL:-

# %%
url="https://www.makemytrip.com/flight/search?itinerary=DEL-BLR-23/04/2022&tripType=O&paxType=A-1_C-0_I-0&intl=false&cabinClass=E&ccde=IN&lang=eng"
driver.get(url)
time.sleep(2)
ad=driver.find_element_by_xpath('//div[@class="overlay"]/div/span').click()
time.sleep(2)
btn=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div[1]/div[2]/div/div[1]/div[2]/div[4]/div/button').click()
time.sleep(2)
for i in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
Airline=[]
source=[]
destination=[]
Arival=[]
Departure=[]
no_of_stops=[]
prices=[]

name=driver.find_elements_by_xpath('//div[@class="makeFlex align-items-center  "]/span')
for i in name:
    Airline.append(i.text)
    
so=driver.find_elements_by_xpath('//div[@class="makeFlex flex-column flightTimeInfo"]/p[2]')
for i in range(len(so)):
    if i%2==0:
        source.append(so[i].text)
    else:
        destination.append(so[i].text)
        
ti=driver.find_elements_by_xpath('//div[@class="makeFlex flex-column flightTimeInfo"]/p/span')
for i in range(len(ti)):
    if i%2==0:
        Arival.append(ti[i].text)
    else:
        Departure.append(ti[i].text)
        
st=driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]/div/p')
for i in st:
    if i.text[0]!='N':
        no_of_stops.append(int(i.text[0]))
    else:
        no_of_stops.append(int('0'))

price=driver.find_elements_by_xpath('//div[@class="textRight flexOne"]/p')
for i in price:
    prices.append(i.text.replace('₹',''))

print(len(Airline))
print(len(source))
print(len(destination))
print(len(Arival))
print(len(Departure))
print(len(no_of_stops))
print(len(prices))
# Out:
# 59
# 59
# 59
# 59
# 59
# 59
# 59

# %%
df= pd.DataFrame({"Airlines_Name":Airline,
                 "Date Of Journey":"23-Apr-2022",
                 "Source":source,
                 "Destination":destination,
                 "Arival":Arival,
                 "Departure":Departure,
                 "No. Of Stoppage":no_of_stops,
                 "Price":prices})

df
# Out:
#    Airlines_Name Date Of Journey     Source Destination Arival Departure  \
# 0       Go First     23-Apr-2022  New Delhi   Bengaluru  02:40     07:45
# 1       Go First     23-Apr-2022  New Delhi   Bengaluru  12:35     20:55
# 2       Go First     23-Apr-2022  New Delhi   Bengaluru  11:30     20:55
# 3       Go First     23-Apr-2022  New Delhi   Bengaluru  15:45     21:45
# 4       Go First     23-Apr-2022  New Delhi   Bengaluru  14:00     21:45
# 5       Go First     23-Apr-2022  New Delhi   Bengaluru  13:10     21:45
# 6       SpiceJet     23-Apr-2022  New Delhi   Bengaluru  14:55     22:30
# 7         IndiGo     23-Apr-2022  New Delhi   Bengaluru  18:00     23:40
# 8         IndiGo     23-Apr-2022  New Delhi   Bengaluru  15:00     23:40
# 9         IndiGo     23-Apr-2022  New Delhi   Bengaluru  13:25     23:40
# 10        IndiGo     23-Apr-2022  New Delhi   Bengaluru  19:30     00:50
# 11      Go First     23-Apr-2022  New Delhi   Bengaluru  22:45     07:45
# 52       Vistara     23-Apr-2022  New Delhi   Bengaluru  19:50     22:40
# 53        IndiGo     23-Apr-2022  New Delhi   Bengaluru  11:30     14:15
# 54       Vistara     23-Apr-2022  New Delhi   Bengaluru  09:05     11:50
# 55     Air India     23-Apr-2022  New Delhi   Bengaluru  09:45     12:30
# 56     Air India     23-Apr-2022  New Delhi   Bengaluru  13:30     16:15
# 57       Vistara     23-Apr-2022  New Delhi   Bengaluru  17:35     20:25
# 58     Air India     23-Apr-2022  New Delhi   Bengaluru  21:50     00:40
#
#     No. Of Stoppage    Price
# 0                 1    8,159
# 1                 1    8,159
# 2                 1    8,159
# 3                 1    8,159
# 4                 1    8,159
# 5                 1    8,159
# 6                 1    8,159
# 7                 1    8,159
# 8                 1    8,159
# 9                 1    8,159
# 10                1    8,159
# 11                1    8,159
# 12                1    8,346
# 13                1    8,346
# 14                1    8,346
# 15                2    8,346
# 16                1    8,789
# 17                1    9,367
# 18                0    9,682
# 19                0    9,997
# 20                0    9,997
# 21                0   10,050
# 22                0   10,050
# 23                0   10,104
# 24                0   10,259
# 25                0   10,417
# 26                1   10,686
# 27                0   10,837
# 28                0   10,889
# 29                1   11,178
# 30                0   11,519
# 31                0   11,519
# 32                1   11,939
# 33                0   12,360
# 34                1   12,837
# 35                0   13,284
# 36                0   13,304
# 37                0   13,305
# 38                1   13,357
# 39                0   14,354
# 40                0   14,354
# 41                1   14,612
# 42                0   14,875
# 43                0   14,875
# 44                0   14,875
# 45                0   14,879
# 46                0   14,879
# 47                0   14,879
# 48                0   15,719
# 49                0   15,751
# 50                0   16,770
# 51                0   16,770
# 52                0   16,770
# 53                0   17,504
# 54                0   20,340
# 55                0   20,340
# 56                0   20,340
# 57                0   20,340
# 58                0   20,340

# %%
url="https://www.makemytrip.com/flight/search?itinerary=BLR-DEL-23/04/2022&tripType=O&paxType=A-1_C-0_I-0&intl=false&cabinClass=E&ccde=IN&lang=eng"
driver.get(url)
time.sleep(2)
for i in range(200):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
Airline=[]
source=[]
destination=[]
Arival=[]
Departure=[]
no_of_stops=[]
prices=[]

name=driver.find_elements_by_xpath('//div[@class="makeFlex align-items-center  "]/span')
for i in name:
    Airline.append(i.text)
    
so=driver.find_elements_by_xpath('//div[@class="makeFlex flex-column flightTimeInfo"]/p[2]')
for i in range(len(so)):
    if i%2==0:
        source.append(so[i].text)
    else:
        destination.append(so[i].text)
        
ti=driver.find_elements_by_xpath('//div[@class="makeFlex flex-column flightTimeInfo"]/p/span')
for i in range(len(ti)):
    if i%2==0:
        Arival.append(ti[i].text)
    else:
        Departure.append(ti[i].text)
        
st=driver.find_elements_by_xpath('//div[@class="stop-info flexOne"]/div/p')
for i in st:
    if i.text[0]!='N':
        no_of_stops.append(int(i.text[0]))
    else:
        no_of_stops.append(int('0'))

price=driver.find_elements_by_xpath('//div[@class="textRight flexOne"]/p')
for i in price:
    prices.append(i.text.replace('₹',''))

print(len(Airline))
print(len(source))
print(len(destination))
print(len(Arival))
print(len(Departure))
print(len(no_of_stops))
print(len(prices))
# Out:
# 47
# 47
# 47
# 47
# 47
# 47
# 36           Vistara     23-Apr-2022  Bengaluru   New Delhi  17:45     20:20
# 37         Air India     23-Apr-2022  Bengaluru   New Delhi  13:20     15:40
# 38            IndiGo     23-Apr-2022  Bengaluru   New Delhi  07:10     12:10
# 39  Star Air, IndiGo     23-Apr-2022  Bengaluru   New Delhi  07:05     13:55
# 40           Vistara     23-Apr-2022  Bengaluru   New Delhi  08:00     10:40
# 41           Vistara     23-Apr-2022  Bengaluru   New Delhi  09:45     12:40
# 42         Air India     23-Apr-2022  Bengaluru   New Delhi  10:00     12:50
# 43         Air India     23-Apr-2022  Bengaluru   New Delhi  17:00     19:50
# 44           Vistara     23-Apr-2022  Bengaluru   New Delhi  11:30     14:10
# 45           AirAsia     23-Apr-2022  Bengaluru   New Delhi  06:10     08:55
# 46           AirAsia     23-Apr-2022  Bengaluru   New Delhi  11:15     13:55
#
#     No. Of Stoppage    Price
# 0                 0    8,419
# 1                 0    8,419
# 2                 0    8,419
# 3                 0    8,419
# 4                 0    8,419
# 5                 0    8,419
# 6                 0    8,419
# 7                 1    8,419
# 8                 0    8,892
# 9                 1    9,049
# 10                1    9,049
# 11                0    9,259
# 12                0    9,312
# 13                0    9,469
# 14                1    9,679
# 15                1    9,679
# 16                0    9,942
# 17                0    9,942
# 18                0    9,942
# 19                0   10,309
# 20                0   10,519
# 21                0   10,603
# 22                1   11,438
# 23                1   12,147
# 24                0   12,304
# 25                0   12,304
# 26                0   12,304
# 27                0   12,304
# 28                0   12,304
# 29                1   12,514
# 30                0   13,141
# 31                0   13,141
# 32                1   13,321
# 33                0   13,564
# 34                0   13,564
# 35                0   13,564
# 36                0   13,564
# 37                0   13,774
# 38                1   13,879
# 39                1   14,568
# 40                0   15,139
# 41                0   15,139
# 42                0   15,349
# 43                0   15,349
# 44                0   17,029
# 45                0   20,598
# 46                0   20,598

# %%
tdf = pd.concat([df,df1],axis = 0, ignore_index=True)
tdf
# Out:
#     Airlines_Name Date Of Journey     Source Destination Arival Departure  \
# 0        Go First     23-Apr-2022  New Delhi   Bengaluru  02:40     07:45
# 1        Go First     23-Apr-2022  New Delhi   Bengaluru  12:35     20:55
# 2        Go First     23-Apr-2022  New Delhi   Bengaluru  11:30     20:55
# 3        Go First     23-Apr-2022  New Delhi   Bengaluru  15:45     21:45
# 4        Go First     23-Apr-2022  New Delhi   Bengaluru  14:00     21:45
# ..            ...             ...        ...         ...    ...       ...
# 101     Air India     23-Apr-2022  Bengaluru   New Delhi  10:00     12:50
# 102     Air India     23-Apr-2022  Bengaluru   New Delhi  17:00     19:50
# 103       Vistara     23-Apr-2022  Bengaluru   New Delhi  11:30     14:10
# 104       AirAsia     23-Apr-2022  Bengaluru   New Delhi  06:10     08:55
# 105       AirAsia     23-Apr-2022  Bengaluru   New Delhi  11:15     13:55
#
#      No. Of Stoppage    Price
# 0                  1    8,159
# 1                  1    8,159
# 2                  1    8,159
# 3                  1    8,159
# 4                  1    8,159
# ..               ...      ...
# 101                0   15,349
# 102                0   15,349
# 103                0   17,029
# 104                0   20,598
# 105                0   20,598
#
# [106 rows x 8 columns]

# %%
tdf.to_csv("Flight_Price.csv")
